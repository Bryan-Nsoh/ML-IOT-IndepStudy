# %% [markdown]
# ### Understanding the data
# Digging into the file to understand its structure and contents

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_and_visualize(df):
    # Basic Data Characteristics
    print("Representative Example from the Dataset:")
    print(df.iloc[0])
    
    print("\nDataset Characteristics:")
    print(f"Total number of items: {len(df)}")
    print("Data types of each column:")
    print(df.dtypes)

    # Data Quality Assessment
    print("\nData Quality Assessment:")
    print("Number of missing values in each column:")
    print(df.isnull().sum())

    # Create and Display Box Plots for Each Numeric Column
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
    num_plots = len(numeric_columns)
    num_rows = num_plots // 2 + num_plots % 2
    fig, axes = plt.subplots(num_rows, 2, figsize=(10, num_rows * 5))
    axes = axes.flatten()

    for i, column in enumerate(numeric_columns):
        sns.boxplot(x=df[column], ax=axes[i])
        axes[i].set_title(column)
        axes[i].set_xlabel('')

    if num_plots % 2 != 0:
        axes[-1].axis('off')

    plt.tight_layout()
    plt.show()

    # Sample 10% of the Data for Further Visualization
    data_sample = df.sample(frac=0.1)

    # Distribution of Fare Amount
    plt.figure(figsize=(8, 6))
    sns.histplot(data_sample['fare_amount'], kde=True)
    plt.title('Distribution of Fare Amount')
    plt.xlabel('Fare Amount')
    plt.ylabel('Frequency')
    plt.show()

    # Distribution of Pickup and Dropoff Locations
    plt.figure(figsize=(10, 8))
    sns.scatterplot(data=data_sample, x='pickup_longitude', y='pickup_latitude', label='Pickup')
    sns.scatterplot(data=data_sample, x='dropoff_longitude', y='dropoff_latitude', color='r', label='Dropoff')
    plt.title('Distribution of Pickup and Dropoff Locations')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.legend()
    plt.show()

    # Distribution of Passenger Count
    data_sample.reset_index(drop=True, inplace=True)
    plt.figure(figsize=(8, 6))
    sns.countplot(x=data_sample['passenger_count'])
    plt.title('Distribution of Passenger Count')
    plt.xlabel('Number of Passengers')
    plt.ylabel('Frequency')
    plt.show()

# Load the dataset in chunks
chunk_size = 50000
chunks = pd.read_csv("train.csv", chunksize=chunk_size)

# Concatenate chunks into a single dataframe
data = pd.concat([chunk for chunk in chunks], axis=0)

# Call the analysis and visualization function
analyze_and_visualize(data)
# Out:
# Representative Example from the Dataset:
# key                  2009-06-15 17:26:21.0000001
# fare_amount                                  4.5
# pickup_datetime          2009-06-15 17:26:21 UTC
# pickup_longitude                      -73.844311
# pickup_latitude                        40.721319
# dropoff_longitude                      -73.84161
# dropoff_latitude                       40.712278
# passenger_count                              1.0
# Name: 0, dtype: object
#
# Dataset Characteristics:
# Total number of items: 15325335
# Data types of each column:
# key                   object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count      float64
# dtype: object
#
# Data Quality Assessment:
# Number of missing values in each column:
# key                    0
# fare_amount            0
# pickup_datetime        0
# pickup_longitude       1
# pickup_latitude        1
# dropoff_longitude    101
# dropoff_latitude     101
# passenger_count        1
# dtype: int64
# Outlier Summary for fare_amount:
# count     15325335
# unique           2
# top          False
# freq      14005787
# Name: fare_amount, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_longitude:
# count     15325335
# unique           2
# top          False
# freq      14284371
# Name: pickup_longitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_latitude:
# count     15325335
# unique           2
# top          False
# freq      14598104
# Name: pickup_latitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_longitude:
# count     15325335
# unique           2
# top          False
# freq      14243205
# Name: dropoff_longitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_latitude:
# count     15325335
# unique           2
# top          False
# freq      14385625
# Name: dropoff_latitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for passenger_count:
# count     15325335
# unique           2
# top          False
# freq      13589306
# Name: passenger_count, dtype: object
# Percentage of Outliers: 100.00%
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### Data cleaning and preprocessing functions
# Computing Haversine distance
# Removing:
#     - unreasonable -ve values
#     - too long distances
#     -  0 < no passengers of > 6
#
# Doing feature engineering for:
#     - time of day
#     - day of week
#     - month of year
#     - year
#     - distance
#     - speed
#     - direction

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# Function to calculate haversine distance
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # radius of Earth in kilometers
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

# Function to calculate cluster labels for pickup locations by applying the KMeans algorithm
def cluster_locations(latitudes, longitudes, n_clusters=10):
    """Cluster latitudes and longitudes using KMeans."""
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    clusters = kmeans.fit_predict(np.vstack((latitudes, longitudes)).T)
    return clusters

# Dictionary of major landmarks in Manhattan
LANDMARKS = {
    "JFK_Airport": (40.6413, -73.7781),
    "LaGuardia_Airport": (40.7769, -73.8740),
    "Central_Park": (40.7851, -73.9683),
    "Times_Square": (40.7580, -73.9855),
}

# Function to calculate distances to major landmarks by applying the haversine function
def calculate_distances_to_landmarks(df):
    """Calculate distances from pickup and dropoff coordinates to major landmarks."""
    for landmark, (lat, lon) in LANDMARKS.items():
        pickup_distance = haversine_distance(
            df['pickup_latitude'], df['pickup_longitude'], lat, lon
        )
        dropoff_distance = haversine_distance(
            df['dropoff_latitude'], df['dropoff_longitude'], lat, lon
        )
        df.loc[:, f"pickup_distance_to_{landmark}"] = pickup_distance
        df.loc[:, f"dropoff_distance_to_{landmark}"] = dropoff_distance
    print('Distances to landmarks calculated...')
    return df

# Function to implement time feature engineering by creating new columns for year, month, day, hour, day of week, and whether the day is a weekend
def preprocess_features(df):
    # Distance
    df['distance_km'] = haversine_distance(
        df['pickup_latitude'], 
        df['pickup_longitude'], 
        df['dropoff_latitude'], 
        df['dropoff_longitude']
    )
    print('Distance calculated...')
    
    # Time features
    df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
    df['year'] = df['pickup_datetime'].dt.year
    df['month'] = df['pickup_datetime'].dt.month
    df['day'] = df['pickup_datetime'].dt.day
    df['hour'] = df['pickup_datetime'].dt.hour
    df['day_of_week'] = df['pickup_datetime'].dt.dayofweek
    df['is_weekend'] = (df['day_of_week'] >= 5).astype(int)
    df['is_peak_hour'] = df['hour'].apply(lambda x: 1 if 7 <= x <= 9 or 16 <= x <= 19 else 0)
    print('Time features created...')
    
    
    # Clustering pickup and dropoff locations. Note that kmeans doesn't work with NaNs
    df = df.dropna()
    df.loc[:, 'pickup_cluster'] = cluster_locations(df['pickup_latitude'], df['pickup_longitude'])
    df.loc[:, 'dropoff_cluster'] = cluster_locations(df['dropoff_latitude'], df['dropoff_longitude'])

    print('Location clusters created...')
    
    # Calculate distances to major landmarks
    df = calculate_distances_to_landmarks(df)
    
    return df

# Function to clean the data by removing unrealistic values
def clean_data(df):
    # Remove unrealistic coordinates by refining the bounding box around NYC
    bounding_box = {
        'min_long': -74.05,
        'min_lat': 40.63,
        'max_long': -73.75,
        'max_lat': 40.85
    }
    df = df[
        (df['pickup_longitude'] >= bounding_box['min_long']) & 
        (df['pickup_longitude'] <= bounding_box['max_long']) &
        (df['pickup_latitude'] >= bounding_box['min_lat']) & 
        (df['pickup_latitude'] <= bounding_box['max_lat']) &
        (df['dropoff_longitude'] >= bounding_box['min_long']) & 
        (df['dropoff_longitude'] <= bounding_box['max_long']) &
        (df['dropoff_latitude'] >= bounding_box['min_lat']) & 
        (df['dropoff_latitude'] <= bounding_box['max_lat'])
    ]

    # Remove entries where fare amount is less than $2.5 (minimum fare) and greater than $100
    df = df[(df['fare_amount'] >= 2.5) & (df['fare_amount'] <= 100)]
    
    # Remove entries where the distance is too long to be realistic for a taxi trip in NYC
    df = df[df['distance_km'] <= 100]

    # Remove data points where passenger count is outside the range 1 to 6
    df = df[(df['passenger_count'] >= 1) & (df['passenger_count'] <= 6)]

    # Remove data points that are outside the 1.5 * IQR range for fare_amount
    Q1_fare = df['fare_amount'].quantile(0.25)
    Q3_fare = df['fare_amount'].quantile(0.75)
    IQR_fare = Q3_fare - Q1_fare
    df = df[~((df['fare_amount'] < (Q1_fare - 1.5 * IQR_fare)) | (df['fare_amount'] > (Q3_fare + 1.5 * IQR_fare)))]

    # Remove null values
    df = df.dropna()
    
    return df

# Function to preprocess test data without removing outliers
def preprocess_test_data(df):
    # Apply haversine distance and clustering functions
    df = preprocess_features(df)
    df = df.dropna()
    df.loc[:, 'pickup_cluster'] = cluster_locations(df['pickup_latitude'], df['pickup_longitude'])
    df.loc[:, 'dropoff_cluster'] = cluster_locations(df['dropoff_latitude'], df['dropoff_longitude'])
    
    # Calculate distances to major landmarks
    df = calculate_distances_to_landmarks(df)
    df = add_feature_interactions_and_binning(df)
    
    return df

# Function to add interaction features and binning
def add_feature_interactions_and_binning(df):
    # Interaction Features
    df['pickup_lat_lon_interaction'] = df['pickup_latitude'] * df['pickup_longitude']
    df['dropoff_lat_lon_interaction'] = df['dropoff_latitude'] * df['dropoff_longitude']

    # Binning hours into different parts of the day
    bins = [0, 6, 12, 18, 24]
    labels = [0, 1, 2, 3]  # 0: night, 1: morning, 2: afternoon, 3: evening
    df['part_of_day'] = pd.cut(df['hour'], bins=bins, labels=labels, include_lowest=True).astype(int)
    
    # drop nan values
    df = df.dropna()
    
    print('Interaction features and binning created...')
    
    return df

    
# Now, we use the functions defined above to clean and preprocess  
# both the raw and processed training and test data

# FOR TRAINING DATA
# save the raw data and print columns
data_raw = data.copy()
data_raw.to_csv('train_raw.csv', index=False)
print("Raw data columns:", data_raw.columns)

# Preprocess features for feature engineered data
data_fe = preprocess_features(data)
data_fe = clean_data(data_fe)
data_fe = add_feature_interactions_and_binning(data_fe)

# Save the feature engineered data
data_fe.to_csv('train_fe.csv', index=False)
print("Feature engineered data columns:", data_fe.columns)
# visualize the data
analyze_and_visualize(data_fe)


# FOR TEST DATA
# Load the test dataset
test_data = pd.read_csv("test.csv")

# Save the raw test data and print columns
test_data_raw = test_data.copy()
test_data_raw.to_csv('test_raw.csv', index=False)
print("Raw test data columns:", test_data_raw.columns)

# Preprocess features for feature engineered test data
test_data_fe = preprocess_test_data(test_data)

# Save the feature engineered test data
test_data_fe.to_csv('test_fe.csv', index=False)
print("Feature engineered test data columns:", test_data_fe.columns)
# Out:
# Raw data columns: Index(['key', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count'],
#       dtype='object')
# Distance calculated...
# Time features created...
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'pickup_cluster'] = cluster_locations(df['pickup_latitude'], df['pickup_longitude'])
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'dropoff_cluster'] = cluster_locations(df['dropoff_latitude'], df['dropoff_longitude'])
# Location clusters created...
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"pickup_distance_to_{landmark}"] = pickup_distance
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"dropoff_distance_to_{landmark}"] = dropoff_distance
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"pickup_distance_to_{landmark}"] = pickup_distance
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"dropoff_distance_to_{landmark}"] = dropoff_distance
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"pickup_distance_to_{landmark}"] = pickup_distance
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"dropoff_distance_to_{landmark}"] = dropoff_distance
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"pickup_distance_to_{landmark}"] = pickup_distance
# C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_25316\1693481150.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"dropoff_distance_to_{landmark}"] = dropoff_distance
# Distances to landmarks calculated...
# Interaction features and binning created...
# Feature engineered data columns: Index(['key', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count', 'distance_km', 'year', 'month', 'day', 'hour',
#        'day_of_week', 'is_weekend', 'is_peak_hour', 'pickup_cluster',
#        'dropoff_cluster', 'pickup_distance_to_JFK_Airport',
#        'dropoff_distance_to_JFK_Airport',
#        'pickup_distance_to_LaGuardia_Airport',
#        'dropoff_distance_to_LaGuardia_Airport',
#        'pickup_distance_to_Central_Park', 'dropoff_distance_to_Central_Park',
#        'pickup_distance_to_Times_Square', 'dropoff_distance_to_Times_Square',
#        'pickup_lat_lon_interaction', 'dropoff_lat_lon_interaction',
#        'part_of_day'],
#       dtype='object')
# Representative Example from the Dataset:
# key                                      2009-06-15 17:26:21.0000001
# fare_amount                                                      4.5
# pickup_datetime                            2009-06-15 17:26:21+00:00
# pickup_longitude                                          -73.844311
# pickup_latitude                                            40.721319
# dropoff_longitude                                          -73.84161
# dropoff_latitude                                           40.712278
# passenger_count                                                  1.0
# distance_km                                                 1.030764
# year                                                            2009
# month                                                              6
# day                                                               15
# hour                                                              17
# day_of_week                                                        0
# is_weekend                                                         0
# is_peak_hour                                                       1
# pickup_cluster                                                     1
# dropoff_cluster                                                    0
# pickup_distance_to_JFK_Airport                             10.504346
# dropoff_distance_to_JFK_Airport                             9.538054
# pickup_distance_to_LaGuardia_Airport                        6.667174
# dropoff_distance_to_LaGuardia_Airport                       7.686289
# pickup_distance_to_Central_Park                            12.624397
# dropoff_distance_to_Central_Park                           13.396463
# pickup_distance_to_Times_Square                            12.575088
# dropoff_distance_to_Times_Square                           13.146477
# pickup_lat_lon_interaction                              -3007.037745
# dropoff_lat_lon_interaction                             -3006.260154
# part_of_day                                                        2
# Name: 0, dtype: object
#
# Dataset Characteristics:
# Total number of items: 13608293
# Data types of each column:
# key                                                   object
# fare_amount                                          float64
# pickup_datetime                          datetime64[ns, UTC]
# pickup_longitude                                     float64
# pickup_latitude                                      float64
# dropoff_longitude                                    float64
# dropoff_latitude                                     float64
# passenger_count                                      float64
# distance_km                                          float64
# year                                                   int32
# month                                                  int32
# day                                                    int32
# hour                                                   int32
# day_of_week                                            int32
# is_weekend                                             int32
# is_peak_hour                                           int64
# pickup_cluster                                         int32
# dropoff_cluster                                        int32
# pickup_distance_to_JFK_Airport                       float64
# dropoff_distance_to_JFK_Airport                      float64
# pickup_distance_to_LaGuardia_Airport                 float64
# dropoff_distance_to_LaGuardia_Airport                float64
# pickup_distance_to_Central_Park                      float64
# dropoff_distance_to_Central_Park                     float64
# pickup_distance_to_Times_Square                      float64
# dropoff_distance_to_Times_Square                     float64
# pickup_lat_lon_interaction                           float64
# dropoff_lat_lon_interaction                          float64
# part_of_day                                            int32
# dtype: object
#
# Data Quality Assessment:
# Number of missing values in each column:
# key                                      0
# fare_amount                              0
# pickup_datetime                          0
# pickup_longitude                         0
# pickup_latitude                          0
# dropoff_longitude                        0
# dropoff_latitude                         0
# passenger_count                          0
# distance_km                              0
# year                                     0
# month                                    0
# day                                      0
# hour                                     0
# day_of_week                              0
# is_weekend                               0
# is_peak_hour                             0
# pickup_cluster                           0
# dropoff_cluster                          0
# pickup_distance_to_JFK_Airport           0
# dropoff_distance_to_JFK_Airport          0
# pickup_distance_to_LaGuardia_Airport     0
# dropoff_distance_to_LaGuardia_Airport    0
# pickup_distance_to_Central_Park          0
# dropoff_distance_to_Central_Park         0
# pickup_distance_to_Times_Square          0
# dropoff_distance_to_Times_Square         0
# pickup_lat_lon_interaction               0
# dropoff_lat_lon_interaction              0
# part_of_day                              0
# dtype: int64
# Outlier Summary for fare_amount:
# count     13608293
# unique           2
# top          False
# freq      13191263
# Name: fare_amount, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_longitude:
# count     13608293
# unique           2
# top          False
# freq      13358958
# Name: pickup_longitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_latitude:
# count     13608293
# unique           2
# top          False
# freq      13378717
# Name: pickup_latitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_longitude:
# count     13608293
# unique           2
# top          False
# freq      13264006
# Name: dropoff_longitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_latitude:
# count     13608293
# unique           2
# top          False
# freq      13237316
# Name: dropoff_latitude, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for passenger_count:
# count     13608293
# unique           2
# top          False
# freq      12067625
# Name: passenger_count, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for distance_km:
# count     13608293
# unique           2
# top          False
# freq      13025926
# Name: distance_km, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for is_peak_hour:
# count     13608293
# unique           1
# top          False
# freq      13608293
# Name: is_peak_hour, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_distance_to_JFK_Airport:
# count     13608293
# unique           2
# top          False
# freq      12966442
# Name: pickup_distance_to_JFK_Airport, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_distance_to_JFK_Airport:
# count     13608293
# unique           2
# top          False
# freq      12642169
# Name: dropoff_distance_to_JFK_Airport, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_distance_to_LaGuardia_Airport:
# count     13608293
# unique           2
# top          False
# freq      13436742
# Name: pickup_distance_to_LaGuardia_Airport, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_distance_to_LaGuardia_Airport:
# count     13608293
# unique           2
# top          False
# freq      13378271
# Name: dropoff_distance_to_LaGuardia_Airport, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_distance_to_Central_Park:
# count     13608293
# unique           2
# top          False
# freq      13477121
# Name: pickup_distance_to_Central_Park, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_distance_to_Central_Park:
# count     13608293
# unique           2
# top          False
# freq      13388425
# Name: dropoff_distance_to_Central_Park, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_distance_to_Times_Square:
# count     13608293
# unique           2
# top          False
# freq      13276100
# Name: pickup_distance_to_Times_Square, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_distance_to_Times_Square:
# count     13608293
# unique           2
# top          False
# freq      13130370
# Name: dropoff_distance_to_Times_Square, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for pickup_lat_lon_interaction:
# count     13608293
# unique           2
# top          False
# freq      13066088
# Name: pickup_lat_lon_interaction, dtype: object
# Percentage of Outliers: 100.00%
#
# Outlier Summary for dropoff_lat_lon_interaction:
# count     13608293
# unique           2
# top          False
# freq      12841851
# Name: dropoff_lat_lon_interaction, dtype: object
# Percentage of Outliers: 100.00%
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Raw test data columns: Index(['key', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count'],
#       dtype='object')
# Distance calculated...
# Time features created...
# Location clusters created...
# Distances to landmarks calculated...
# Distances to landmarks calculated...
# Interaction features and binning created...
# Feature engineered test data columns: Index(['key', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count',
#        'distance_km', 'year', 'month', 'day', 'hour', 'day_of_week',
#        'is_weekend', 'is_peak_hour', 'pickup_cluster', 'dropoff_cluster',
#        'pickup_distance_to_JFK_Airport', 'dropoff_distance_to_JFK_Airport',
#        'pickup_distance_to_LaGuardia_Airport',
#        'dropoff_distance_to_LaGuardia_Airport',
#        'pickup_distance_to_Central_Park', 'dropoff_distance_to_Central_Park',
#        'pickup_distance_to_Times_Square', 'dropoff_distance_to_Times_Square',
#        'pickup_lat_lon_interaction', 'dropoff_lat_lon_interaction',
#        'part_of_day'],
#       dtype='object')

# %% [markdown]
# # Encoding categorical features and preparing data for both XGBoost and ANN
# - One-hot encoding for categorical features to convert them into a format that can be provided to both XGBoost and ANN models.
#  - Standard scaling for continuous features to normalize their distribution, mainly for optimal ANN performance, though it won't negatively impact XGBoost.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Load the feature-engineered training data
train_fe_df = pd.read_csv('train_fe.csv')

# Print columns of the feature-engineered data
print("Initial feature-engineered data columns:", train_fe_df.columns.tolist())

# Define continuous and categorical features
continuous_features = [
    'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
    'distance_km', 'pickup_distance_to_JFK_Airport', 'pickup_distance_to_LaGuardia_Airport',
    'pickup_distance_to_Central_Park', 'pickup_distance_to_Times_Square',
    'dropoff_distance_to_JFK_Airport', 'dropoff_distance_to_LaGuardia_Airport',
    'dropoff_distance_to_Central_Park', 'dropoff_distance_to_Times_Square'
]
categorical_features = [
    'year', 'month', 'day', 'hour', 'day_of_week',
    'is_weekend', 'is_peak_hour', 'part_of_day',
    'pickup_cluster', 'dropoff_cluster'
]

# Check that the features specified are present in the DataFrame
assert all(feature in train_fe_df.columns for feature in continuous_features + categorical_features), \
    "Some features are not in the DataFrame columns."

# Create the preprocessing pipelines for both numerical and categorical data
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(drop='first')

# Combine the numeric and categorical transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, continuous_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Fit the preprocessor to the training data and transform the data
X_train_fe = preprocessor.fit_transform(train_fe_df.drop('fare_amount', axis=1))

# Debugging step to check the shape after transformation
print("Transformed feature shape:", X_train_fe.shape)

# Get the feature names for the transformed data
encoded_feature_names = preprocessor.get_feature_names_out()

# Debugging step to ensure the feature names and transformed shape match
print("Number of encoded feature names:", len(encoded_feature_names))
assert X_train_fe.shape[1] == len(encoded_feature_names), \
    "Mismatch in the number of transformed features and encoded feature names."

# Convert the transformed features back to a DataFrame
X_train_fe_df = pd.DataFrame(X_train_fe.toarray(), columns=encoded_feature_names)  # .toarray() converts sparse matrix to dense

# Debugging step to check if the DataFrame conversion added any unexpected columns
print("Columns after DataFrame conversion:", X_train_fe_df.columns.tolist())
assert len(X_train_fe_df.columns) == len(encoded_feature_names), \
    "Mismatch in DataFrame columns after conversion."

# Add the target column back to the DataFrame
X_train_fe_df['fare_amount'] = train_fe_df['fare_amount'].copy()

# Debugging step to check the final DataFrame shape
print("Final DataFrame shape:", X_train_fe_df.shape)

# Save the encoded DataFrame to CSV
X_train_fe_df.to_csv('train_fe_encoded.csv', index=False)

# Final debugging step to confirm the save was successful
print("Encoded training data saved to 'train_fe_encoded.csv'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\bnsoh2\OneDrive - University of Nebraska-Lincoln\Documents\Courses\CESE 878\NY_taxi\NY_taxi_data_processing.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_data_processing.ipynb#X11sZmlsZQ%3D%3D?line=36'>37</a> # Convert the transformed features back to a dataframe
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_data_processing.ipynb#X11sZmlsZQ%3D%3D?line=37'>38</a> encoded_feature_names = preprocessor.get_feature_names_out()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_data_processing.ipynb#X11sZmlsZQ%3D%3D?line=38'>39</a> X_train_fe_df = pd.DataFrame(X_train_fe, columns=encoded_feature_names)
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_data_processing.ipynb#X11sZmlsZQ%3D%3D?line=40'>41</a> # Add the target column back to the dataframe
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_data_processing.ipynb#X11sZmlsZQ%3D%3D?line=41'>42</a> X_train_fe_df['fare_amount'] = y_train_fe
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\pandas\core\frame.py:825, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     817         mgr = arrays_to_mgr(
#     818             arrays,
#     819             columns,
#    (...)
#     822             typ=manager,
#     823         )
#     824     else:
# --> 825         mgr = ndarray_to_mgr(
#     826             data,
#     827             index,
#     828             columns,
#     829             dtype=dtype,
#     830             copy=copy,
#     831             typ=manager,
#     832         )
#     833 else:
#     834     mgr = dict_to_mgr(
#     835         {},
#     836         index,
#    (...)
#     839         typ=manager,
#     840     )
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (13608293, 1), indices imply (13608293, 94)

# %% [markdown]
# # Begin by training with linear regression

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Load the encoded and raw datasets
train_fe_encoded_df = pd.read_csv('train_fe_encoded.csv')
train_raw_df = pd.read_csv('train_raw.csv')

# Split the feature-engineered dataset into training and validation sets
X_train_fe, X_val_fe, y_train_fe, y_val_fe = train_test_split(
    train_fe_encoded_df.drop('fare_amount', axis=1),
    train_fe_encoded_df['fare_amount'],
    test_size=0.2,
    random_state=42
)

# Split the raw dataset into training and validation sets
X_train_raw, X_val_raw, y_train_raw, y_val_raw = train_test_split(
    train_raw_df.drop('fare_amount', axis=1),
    train_raw_df['fare_amount'],
    test_size=0.2,
    random_state=42
)

# Initialize the Linear Regression model
lr = LinearRegression()

# Train the model using the feature-engineered data
lr.fit(X_train_fe, y_train_fe)

# Predict on the validation set
y_val_pred_fe = lr.predict(X_val_fe)

# Evaluate the model using RMSE
rmse_fe = mean_squared_error(y_val_fe, y_val_pred_fe, squared=False)
print(f'Validation RMSE with Feature Engineered Data: {rmse_fe:.2f}')

# Train the model using the raw data
# Note: If the raw data contains categorical features, they need to be encoded before this step.
lr.fit(X_train_raw, y_train_raw)

# Predict on the validation set
y_val_pred_raw = lr.predict(X_val_raw)

# Evaluate the model using RMSE
rmse_raw = mean_squared_error(y_val_raw, y_val_pred_raw, squared=False)
print(f'Validation RMSE with Raw Data: {rmse_raw:.2f}')
# Out:
# Training RMSE: 4.52
# Validation RMSE: 4.55

# %% [markdown]
# # Exploring other methods
# - Trying xgb boost

# %%
import xgboost as xgb

# Update the features list in case it's changed
features = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'distance_km', 'year', 'month', 'day', 'hour', 'day_of_week']

# Create data matrices for XGBoost
dtrain = xgb.DMatrix(X_train[features], label=y_train)
dval = xgb.DMatrix(X_val[features], label=y_val)

# Define parameters for XGBoost
param = {
    'max_depth': 5,  # the maximum depth of each tree
    'eta': 0.3,  # the training step for each iteration
    'objective': 'reg:squarederror',  # loss function to be minimized
}

# # Parameters for XGBoost
# param = {
#     'booster': 'dart',
#     'lambda': 0.9883486193114672,
#     'alpha': 3.7898930992079444e-07,
#     'max_depth': 13,
#     'eta': 0.47910522529499106,
#     'gamma': 0.4089059768531368,
#     'grow_policy': 'lossguide',
#     'objective': 'reg:squarederror',
#     'eval_metric': 'rmse'
# }

# Train XGBoost model
num_round = 100
bst = xgb.train(param, dtrain, num_round, [(dtrain, 'train'), (dval, 'val')], early_stopping_rounds=10)

# Predictions using XGBoost on validation set
y_val_pred_xgb = bst.predict(dval)

# Evaluate XGBoost Model
val_rmse_xgb = np.sqrt(mean_squared_error(y_val, y_val_pred_xgb))
print(f"Validation RMSE (XGBoost): {val_rmse_xgb:.2f}")
# Out:
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:312: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\data.py:440: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\core.py:617: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [0]	train-rmse:8.11540	val-rmse:8.14330
# [1]	train-rmse:5.22436	val-rmse:5.30630
# [2]	train-rmse:4.05043	val-rmse:4.19923
# [3]	train-rmse:3.62334	val-rmse:3.81864
# [4]	train-rmse:3.46339	val-rmse:3.69794
# [5]	train-rmse:3.39012	val-rmse:3.65104
# [6]	train-rmse:3.33709	val-rmse:3.62914
# [7]	train-rmse:3.30320	val-rmse:3.61319
# [8]	train-rmse:3.26972	val-rmse:3.60714
# [9]	train-rmse:3.23402	val-rmse:3.60290
# [10]	train-rmse:3.21036	val-rmse:3.58926
# [11]	train-rmse:3.18095	val-rmse:3.58033
# [12]	train-rmse:3.15554	val-rmse:3.58036
# [13]	train-rmse:3.13045	val-rmse:3.58287
# [14]	train-rmse:3.11121	val-rmse:3.58028
# [15]	train-rmse:3.08208	val-rmse:3.57967
# [16]	train-rmse:3.06776	val-rmse:3.57907
# [17]	train-rmse:3.04680	val-rmse:3.57981
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\bnsoh2\OneDrive - University of Nebraska-Lincoln\Documents\Courses\CESE 878\NY_taxi\NY_taxi_v2.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_v2.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a> # Train XGBoost model
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_v2.ipynb#X12sZmlsZQ%3D%3D?line=23'>24</a> num_round = 100
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_v2.ipynb#X12sZmlsZQ%3D%3D?line=24'>25</a> bst = xgb.train(param, dtrain, num_round, [(dtrain, 'train'), (dval, 'val')], early_stopping_rounds=10)
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_v2.ipynb#X12sZmlsZQ%3D%3D?line=26'>27</a> # Predictions using XGBoost on validation set
#      <a href='vscode-notebook-cell:/c%3A/Users/bnsoh2/OneDrive%20-%20University%20of%20Nebraska-Lincoln/Documents/Courses/CESE%20878/NY_taxi/NY_taxi_v2.ipynb#X12sZmlsZQ%3D%3D?line=27'>28</a> y_val_pred_xgb = bst.predict(dval)
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\training.py:186, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     184         break
#     185     bst.update(dtrain, i, obj)
# --> 186     if cb_container.after_iteration(bst, i, dtrain, evals):
#     187         break
#     189 bst = cb_container.after_training(bst)
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\callback.py:240, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     238 for _, name in evals:
#     239     assert name.find('-') == -1, 'Dataset name should not contain `-`'
# --> 240 score: str = model.eval_set(evals, epoch, self.metric, self._output_margin)
#     241 splited = score.split()[1:]  # into datasets
#     242 # split up `test-error:0.1234`
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\core.py:1989, in Booster.eval_set(self, evals, iteration, feval, output_margin)
#    1986 evnames = c_array(ctypes.c_char_p, [c_str(d[1]) for d in evals])
#    1987 msg = ctypes.c_char_p()
#    1988 _check_call(
# -> 1989     _LIB.XGBoosterEvalOneIter(
#    1990         self.handle,
#    1991         ctypes.c_int(iteration),
#    1992         dmats,
#    1993         evnames,
#    1994         c_bst_ulong(len(evals)),
#    1995         ctypes.byref(msg),
#    1996     )
#    1997 )
#    1998 assert msg.value is not None
#    1999 res = msg.value.decode()  # pylint: disable=no-member
#
# KeyboardInterrupt:

# %% [markdown]
# # Adding Feature interaction and binning

# %% [markdown]
# ### Using  bayesian optimization in optuna to find the optimal hyperparameters for xgboost

# %%
import optuna

# Define the objective function for optimization
def objective(trial):
    # Define search space
    param = {
        'objective': 'reg:squarederror',
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'lambda': trial.suggest_float('lambda', 1e-8, 1.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-8, 1.0, log=True)
    }
    
    if param['booster'] == 'gbtree' or param['booster'] == 'dart':
        param['max_depth'] = trial.suggest_int('max_depth', 1, 15)
        param['eta'] = trial.suggest_float('eta', 1e-8, 7.0, log=True)
        param['gamma'] = trial.suggest_float('gamma', 1e-8, 1.0, log=True)
        param['grow_policy'] = trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide'])

    bst_trial = xgb.train(param, dtrain, evals=[(dval, "validation")], verbose_eval=False, early_stopping_rounds=10)
    y_val_pred_trial = bst_trial.predict(dval)
    rmse = np.sqrt(mean_squared_error(y_val, y_val_pred_trial))
    return rmse

# Create an Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=200)

# Results
print('Number of finished trials: ', len(study.trials))
print('Best trial:')
trial = study.best_trial
print('Value: ', trial.value)
print('Params: ')
for key, value in trial.params.items():
    print(f'    {key}: {value}')
# Out:
# [I 2023-09-08 10:36:07,644] A new study created in memory with name: no-name-e833966e-5cf7-4e95-914d-3b8950df4f19
# [I 2023-09-08 10:36:18,150] Trial 0 finished with value: 14.349968471407534 and parameters: {'booster': 'gbtree', 'lambda': 0.0024047378153110852, 'alpha': 0.01620079851653324, 'max_depth': 3, 'eta': 2.3219256447667452e-05, 'gamma': 3.69192911590725e-05, 'grow_policy': 'depthwise'}. Best is trial 0 with value: 14.349968471407534.
# [I 2023-09-08 10:36:30,362] Trial 1 finished with value: 6.741160990496008 and parameters: {'booster': 'dart', 'lambda': 1.4924576524192281e-05, 'alpha': 3.4726527888057517e-07, 'max_depth': 2, 'eta': 0.10156069664022951, 'gamma': 0.1299765301387184, 'grow_policy': 'lossguide'}. Best is trial 1 with value: 6.741160990496008.
# [W 2023-09-08 10:36:36,256] Trial 2 failed with parameters: {'booster': 'gbtree', 'lambda': 9.422362125860402e-05, 'alpha': 1.0354170630211231e-08, 'max_depth': 4, 'eta': 8.447041726908963e-06, 'gamma': 0.0001888676305462401, 'grow_policy': 'depthwise'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\bnsoh2\AppData\Local\Temp\ipykernel_28392\766166723.py", line 19, in objective
#     bst_trial = xgb.train(param, dtrain, evals=[(dval, "validation")], verbose_eval=False, early_stopping_rounds=10)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2023-09-08 10:36:36,266] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 26
#      24 # Create an Optuna study
#      25 study = optuna.create_study(direction='minimize')
# ---> 26 study.optimize(objective, n_trials=200)
#      28 # Results
#      29 print('Number of finished trials: ', len(study.trials))
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\optuna\study\study.py:442, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     339 def optimize(
#     340     self,
#     341     func: ObjectiveFuncType,
#    (...)
#     348     show_progress_bar: bool = False,
#     349 ) -> None:
#     350     """Optimize an objective function.
#     351
#     352     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     440             If nested invocation of this method occurs.
#     441     """
# --> 442     _optimize(
#     443         study=self,
#     444         func=func,
#     445         n_trials=n_trials,
#     446         timeout=timeout,
#     447         n_jobs=n_jobs,
#     448         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     449         callbacks=callbacks,
#     450         gc_after_trial=gc_after_trial,
#     451         show_progress_bar=show_progress_bar,
#     452     )
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[7], line 19, in objective(trial)
#      16     param['gamma'] = trial.suggest_float('gamma', 1e-8, 1.0, log=True)
#      17     param['grow_policy'] = trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide'])
# ---> 19 bst_trial = xgb.train(param, dtrain, evals=[(dval, "validation")], verbose_eval=False, early_stopping_rounds=10)
#      20 y_val_pred_trial = bst_trial.predict(dval)
#      21 rmse = np.sqrt(mean_squared_error(y_val, y_val_pred_trial))
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File c:\Users\bnsoh2\Desktop\venvs\ml_env\Lib\site-packages\xgboost\core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
